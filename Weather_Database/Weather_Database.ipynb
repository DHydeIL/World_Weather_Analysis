# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the time library  
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 793

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1   
    

# Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})


# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass



# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | sao filipe
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | kahului
# Processing Record 5 of Set 1 | aksarka
# Processing Record 6 of Set 1 | nikitinskiy
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | dikson
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | longyearbyen
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | padang
# Processing Record 14 of Set 1 | la ronge
# Processing Record 15 of Set 1 | dalinghe
# City not found. Skipping...
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 1 | coquimbo
# Processing Record 20 of Set 1 | chuy
# Processing Record 21 of Set 1 | yerbogachen
# Processing Record 22 of Set 1 | arraial do cabo
# Processing Record 23 of Set 1 | ewa beach
# Processing Record 24 of Set 1 | veraval
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | shache
# Processing Record 28 of Set 1 | upernavik
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | nurota
# Processing Record 31 of Set 1 | cidreira
# Processing Record 32 of Set 1 | bayan
# Processing Record 33 of Set 1 | havelock
# Processing Record 34 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 1 | aksay
# Processing Record 36 of Set 1 | tongliao
# Processing Record 37 of Set 1 | sambava
# Processing Record 38 of Set 1 | madera
# Processing Record 39 of Set 1 | sioux lookout
# Processing Record 40 of Set 1 | lorengau
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | avera
# Processing Record 43 of Set 1 | progreso
# Processing Record 44 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 1 | groningen
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | berlevag
# Processing Record 48 of Set 1 | gat
# Processing Record 49 of Set 1 | half moon bay
# Processing Record 50 of Set 1 | kaitangata
# Processing Record 1 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 2 | zaysan
# Processing Record 3 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 2 | saint-philippe
# Processing Record 5 of Set 2 | baykit
# Processing Record 6 of Set 2 | bilma
# Processing Record 7 of Set 2 | dingle
# Processing Record 8 of Set 2 | povenets
# Processing Record 9 of Set 2 | magui
# City not found. Skipping...
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | klaksvik
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | qaanaaq
# Processing Record 14 of Set 2 | san lorenzo
# Processing Record 15 of Set 2 | seoul
# Processing Record 16 of Set 2 | baghdad
# Processing Record 17 of Set 2 | ponta do sol
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | cherskiy
# Processing Record 21 of Set 2 | rikitea
# Processing Record 22 of Set 2 | askiz
# Processing Record 23 of Set 2 | surskoye
# Processing Record 24 of Set 2 | clyde river
# Processing Record 25 of Set 2 | ixtapa
# Processing Record 26 of Set 2 | murashi
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | mar del plata
# Processing Record 29 of Set 2 | alamosa
# Processing Record 30 of Set 2 | kapitanivka
# Processing Record 31 of Set 2 | laguna
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | ayia anna
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | oktyabrskiy
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | santa cruz
# Processing Record 38 of Set 2 | punta arenas
# Processing Record 39 of Set 2 | lumphat
# Processing Record 40 of Set 2 | port augusta
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | talnakh
# Processing Record 43 of Set 2 | nogliki
# Processing Record 44 of Set 2 | taltal
# Processing Record 45 of Set 2 | maurawan
# Processing Record 46 of Set 2 | kruisfontein
# Processing Record 47 of Set 2 | carutapera
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | isangel
# Processing Record 50 of Set 2 | nome
# Processing Record 1 of Set 3 | hasaki
# Processing Record 2 of Set 3 | khatanga
# Processing Record 3 of Set 3 | vestmannaeyjar
# Processing Record 4 of Set 3 | puerto ayacucho
# Processing Record 5 of Set 3 | hermanus
# Processing Record 6 of Set 3 | albany
# Processing Record 7 of Set 3 | kaseda
# Processing Record 8 of Set 3 | khanpur
# Processing Record 9 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 3 | alice springs
# Processing Record 11 of Set 3 | neijiang
# Processing Record 12 of Set 3 | tailai
# Processing Record 13 of Set 3 | praia
# Processing Record 14 of Set 3 | cody
# Processing Record 15 of Set 3 | burnie
# Processing Record 16 of Set 3 | agas
# Processing Record 17 of Set 3 | sur
# Processing Record 18 of Set 3 | mapiri
# Processing Record 19 of Set 3 | airai
# Processing Record 20 of Set 3 | san vicente
# Processing Record 21 of Set 3 | jalu
# Processing Record 22 of Set 3 | iqaluit
# Processing Record 23 of Set 3 | dunedin
# Processing Record 24 of Set 3 | lagunas
# Processing Record 25 of Set 3 | gao
# Processing Record 26 of Set 3 | nadym
# Processing Record 27 of Set 3 | pokhara
# Processing Record 28 of Set 3 | oranjemund
# Processing Record 29 of Set 3 | sangar
# Processing Record 30 of Set 3 | jamestown
# Processing Record 31 of Set 3 | luena
# Processing Record 32 of Set 3 | mechanicsville
# Processing Record 33 of Set 3 | jining
# Processing Record 34 of Set 3 | ambilobe
# Processing Record 35 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 36 of Set 3 | naantali
# Processing Record 37 of Set 3 | bambous virieux
# Processing Record 38 of Set 3 | ribeira grande
# Processing Record 39 of Set 3 | the valley
# Processing Record 40 of Set 3 | itupiranga
# Processing Record 41 of Set 3 | norman wells
# Processing Record 42 of Set 3 | mubi
# Processing Record 43 of Set 3 | provideniya
# Processing Record 44 of Set 3 | valparaiso
# Processing Record 45 of Set 3 | smithers
# Processing Record 46 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 3 | bredasdorp
# Processing Record 48 of Set 3 | tura
# Processing Record 49 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 3 | klyuchi
# Processing Record 1 of Set 4 | walvis bay
# Processing Record 2 of Set 4 | tazovskiy
# Processing Record 3 of Set 4 | kuytun
# Processing Record 4 of Set 4 | sesimbra
# Processing Record 5 of Set 4 | andros town
# Processing Record 6 of Set 4 | estelle
# Processing Record 7 of Set 4 | paamiut
# Processing Record 8 of Set 4 | astorga
# Processing Record 9 of Set 4 | embu
# Processing Record 10 of Set 4 | tecoanapa
# Processing Record 11 of Set 4 | luderitz
# Processing Record 12 of Set 4 | tasiilaq
# Processing Record 13 of Set 4 | alcaniz
# Processing Record 14 of Set 4 | paragominas
# Processing Record 15 of Set 4 | kristiansund
# Processing Record 16 of Set 4 | puerto ayora
# Processing Record 17 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 4 | formosa
# Processing Record 20 of Set 4 | salalah
# Processing Record 21 of Set 4 | kalevala
# Processing Record 22 of Set 4 | mercedes
# Processing Record 23 of Set 4 | severo-kurilsk
# Processing Record 24 of Set 4 | tabou
# Processing Record 25 of Set 4 | kharp
# Processing Record 26 of Set 4 | constitucion
# Processing Record 27 of Set 4 | mindelo
# Processing Record 28 of Set 4 | mogocha
# Processing Record 29 of Set 4 | samana
# Processing Record 30 of Set 4 | pittsfield
# Processing Record 31 of Set 4 | san quintin
# Processing Record 32 of Set 4 | podor
# Processing Record 33 of Set 4 | camana
# Processing Record 34 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 4 | yining
# Processing Record 36 of Set 4 | waynesville
# Processing Record 37 of Set 4 | mehamn
# Processing Record 38 of Set 4 | dukat
# Processing Record 39 of Set 4 | dunmore town
# Processing Record 40 of Set 4 | ryotsu
# Processing Record 41 of Set 4 | bethel
# Processing Record 42 of Set 4 | mitsamiouli
# Processing Record 43 of Set 4 | hithadhoo
# Processing Record 44 of Set 4 | ayia galini
# Processing Record 45 of Set 4 | ilulissat
# Processing Record 46 of Set 4 | hay river
# Processing Record 47 of Set 4 | pathein
# Processing Record 48 of Set 4 | male
# Processing Record 49 of Set 4 | borogontsy
# Processing Record 50 of Set 4 | lata
# Processing Record 1 of Set 5 | chokurdakh
# Processing Record 2 of Set 5 | banamba
# Processing Record 3 of Set 5 | bluff
# Processing Record 4 of Set 5 | hamilton
# Processing Record 5 of Set 5 | vila do maio
# Processing Record 6 of Set 5 | nanortalik
# Processing Record 7 of Set 5 | bandarbeyla
# Processing Record 8 of Set 5 | rio grande
# Processing Record 9 of Set 5 | kapaa
# Processing Record 10 of Set 5 | barrow
# Processing Record 11 of Set 5 | sechura
# Processing Record 12 of Set 5 | kiruna
# Processing Record 13 of Set 5 | naze
# Processing Record 14 of Set 5 | innisfail
# Processing Record 15 of Set 5 | erzin
# Processing Record 16 of Set 5 | kalianget
# Processing Record 17 of Set 5 | kostomuksha
# Processing Record 18 of Set 5 | chaman
# Processing Record 19 of Set 5 | gorom-gorom
# Processing Record 20 of Set 5 | ancud
# Processing Record 21 of Set 5 | neryungri
# Processing Record 22 of Set 5 | saldanha
# Processing Record 23 of Set 5 | leningradskiy
# Processing Record 24 of Set 5 | saskylakh
# Processing Record 25 of Set 5 | muridke
# Processing Record 26 of Set 5 | hami
# Processing Record 27 of Set 5 | bilibino
# Processing Record 28 of Set 5 | broome
# Processing Record 29 of Set 5 | porto novo
# Processing Record 30 of Set 5 | shingu
# Processing Record 31 of Set 5 | malanje
# Processing Record 32 of Set 5 | tela
# Processing Record 33 of Set 5 | amuntai
# Processing Record 34 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 5 | zhangye
# Processing Record 36 of Set 5 | benguela
# Processing Record 37 of Set 5 | lagoa
# Processing Record 38 of Set 5 | visnes
# Processing Record 39 of Set 5 | homer
# Processing Record 40 of Set 5 | amarillo
# Processing Record 41 of Set 5 | umm lajj
# Processing Record 42 of Set 5 | kanigoro
# Processing Record 43 of Set 5 | victoria
# Processing Record 44 of Set 5 | kavaratti
# Processing Record 45 of Set 5 | lebu
# Processing Record 46 of Set 5 | eyl
# Processing Record 47 of Set 5 | port hardy
# Processing Record 48 of Set 5 | praia da vitoria
# Processing Record 49 of Set 5 | saint-francois
# Processing Record 50 of Set 5 | bubaque
# Processing Record 1 of Set 6 | celestun
# Processing Record 2 of Set 6 | general roca
# Processing Record 3 of Set 6 | burley
# Processing Record 4 of Set 6 | oakdale
# Processing Record 5 of Set 6 | takoradi
# Processing Record 6 of Set 6 | quatre cocos
# Processing Record 7 of Set 6 | moose factory
# Processing Record 8 of Set 6 | narsaq
# Processing Record 9 of Set 6 | nortelandia
# Processing Record 10 of Set 6 | olafsvik
# Processing Record 11 of Set 6 | sistranda
# Processing Record 12 of Set 6 | geraldton
# Processing Record 13 of Set 6 | mikhaylovskoye
# Processing Record 14 of Set 6 | marystown
# Processing Record 15 of Set 6 | faya
# Processing Record 16 of Set 6 | karratha
# Processing Record 17 of Set 6 | carnarvon
# Processing Record 18 of Set 6 | kalaleh
# Processing Record 19 of Set 6 | ayios kirikos
# City not found. Skipping...
# Processing Record 20 of Set 6 | faanui
# Processing Record 21 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 6 | taoudenni
# Processing Record 23 of Set 6 | lompoc
# Processing Record 24 of Set 6 | north bend
# Processing Record 25 of Set 6 | duartina
# Processing Record 26 of Set 6 | torbay
# Processing Record 27 of Set 6 | pangnirtung
# Processing Record 28 of Set 6 | charleston
# Processing Record 29 of Set 6 | byron bay
# Processing Record 30 of Set 6 | novyy urengoy
# Processing Record 31 of Set 6 | aiquile
# Processing Record 32 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 6 | cabedelo
# Processing Record 34 of Set 6 | bay roberts
# Processing Record 35 of Set 6 | abashiri
# Processing Record 36 of Set 6 | bagotville
# Processing Record 37 of Set 6 | vermillion
# Processing Record 38 of Set 6 | killybegs
# Processing Record 39 of Set 6 | sitka
# Processing Record 40 of Set 6 | korla
# Processing Record 41 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 6 | buala
# Processing Record 43 of Set 6 | fort nelson
# Processing Record 44 of Set 6 | adrar
# Processing Record 45 of Set 6 | butaritari
# Processing Record 46 of Set 6 | bengkulu
# Processing Record 47 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 48 of Set 6 | yakovlevo
# Processing Record 49 of Set 6 | minas de barroteran
# Processing Record 50 of Set 6 | colares
# Processing Record 1 of Set 7 | idrinskoye
# Processing Record 2 of Set 7 | limbang
# Processing Record 3 of Set 7 | zyryanka
# Processing Record 4 of Set 7 | belorechensk
# Processing Record 5 of Set 7 | alofi
# Processing Record 6 of Set 7 | spornoye
# Processing Record 7 of Set 7 | cukai
# Processing Record 8 of Set 7 | uvinza
# Processing Record 9 of Set 7 | kualakapuas
# Processing Record 10 of Set 7 | comodoro rivadavia
# Processing Record 11 of Set 7 | santa cruz de tenerife
# Processing Record 12 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 7 | okhotsk
# Processing Record 14 of Set 7 | hirara
# Processing Record 15 of Set 7 | tinskoy
# Processing Record 16 of Set 7 | namatanai
# Processing Record 17 of Set 7 | los llanos de aridane
# Processing Record 18 of Set 7 | sola
# Processing Record 19 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 20 of Set 7 | grand gaube
# Processing Record 21 of Set 7 | kaeo
# Processing Record 22 of Set 7 | surt
# Processing Record 23 of Set 7 | irmo
# Processing Record 24 of Set 7 | warah
# Processing Record 25 of Set 7 | salaga
# Processing Record 26 of Set 7 | almaznyy
# Processing Record 27 of Set 7 | nieuw amsterdam
# Processing Record 28 of Set 7 | tuatapere
# Processing Record 29 of Set 7 | baruun-urt
# Processing Record 30 of Set 7 | nhulunbuy
# Processing Record 31 of Set 7 | dakar
# Processing Record 32 of Set 7 | nizhnevartovsk
# Processing Record 33 of Set 7 | nantucket
# Processing Record 34 of Set 7 | port moresby
# Processing Record 35 of Set 7 | port alfred
# Processing Record 36 of Set 7 | matir
# City not found. Skipping...
# Processing Record 37 of Set 7 | srednekolymsk
# Processing Record 38 of Set 7 | urucara
# Processing Record 39 of Set 7 | freeport
# Processing Record 40 of Set 7 | tessalit
# Processing Record 41 of Set 7 | tutoia
# Processing Record 42 of Set 7 | zasheyek
# Processing Record 43 of Set 7 | pevek
# Processing Record 44 of Set 7 | gumushane
# City not found. Skipping...
# Processing Record 45 of Set 7 | aklavik
# Processing Record 46 of Set 7 | nesebar
# Processing Record 47 of Set 7 | sao miguel do araguaia
# Processing Record 48 of Set 7 | hofn
# Processing Record 49 of Set 7 | san patricio
# Processing Record 50 of Set 7 | moroni
# Processing Record 1 of Set 8 | islamkot
# Processing Record 2 of Set 8 | severnyy
# Processing Record 3 of Set 8 | shaunavon
# Processing Record 4 of Set 8 | kashi
# Processing Record 5 of Set 8 | amazar
# Processing Record 6 of Set 8 | besleney
# Processing Record 7 of Set 8 | kendari
# Processing Record 8 of Set 8 | otane
# Processing Record 9 of Set 8 | grindavik
# Processing Record 10 of Set 8 | zholymbet
# Processing Record 11 of Set 8 | aykhal
# Processing Record 12 of Set 8 | newport
# Processing Record 13 of Set 8 | manokwari
# Processing Record 14 of Set 8 | ahuimanu
# Processing Record 15 of Set 8 | wasilla
# Processing Record 16 of Set 8 | turinskaya sloboda
# Processing Record 17 of Set 8 | batagay-alyta
# Processing Record 18 of Set 8 | tomatlan
# Processing Record 19 of Set 8 | garowe
# Processing Record 20 of Set 8 | lipin bor
# Processing Record 21 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 8 | sinnamary
# Processing Record 23 of Set 8 | ranong
# Processing Record 24 of Set 8 | tilichiki
# Processing Record 25 of Set 8 | urengoy
# Processing Record 26 of Set 8 | quthing
# Processing Record 27 of Set 8 | rio gallegos
# Processing Record 28 of Set 8 | dinan
# Processing Record 29 of Set 8 | gorodishche
# Processing Record 30 of Set 8 | matamba
# Processing Record 31 of Set 8 | tabuk
# Processing Record 32 of Set 8 | sarakhs
# Processing Record 33 of Set 8 | goderich
# Processing Record 34 of Set 8 | ukiah
# Processing Record 35 of Set 8 | puerto penasco
# Processing Record 36 of Set 8 | hokitika
# Processing Record 37 of Set 8 | rundu
# Processing Record 38 of Set 8 | guangyuan
# Processing Record 39 of Set 8 | puro
# Processing Record 40 of Set 8 | lopandino
# Processing Record 41 of Set 8 | wa
# City not found. Skipping...
# Processing Record 42 of Set 8 | guilin
# Processing Record 43 of Set 8 | soc trang
# Processing Record 44 of Set 8 | teya
# Processing Record 45 of Set 8 | lekoni
# Processing Record 46 of Set 8 | esperance
# Processing Record 47 of Set 8 | ahipara
# Processing Record 48 of Set 8 | merauke
# Processing Record 49 of Set 8 | catamarca
# Processing Record 50 of Set 8 | katsuura
# Processing Record 1 of Set 9 | jilin
# Processing Record 2 of Set 9 | gravdal
# Processing Record 3 of Set 9 | gashua
# Processing Record 4 of Set 9 | moranbah
# Processing Record 5 of Set 9 | kifri
# Processing Record 6 of Set 9 | sasolburg
# Processing Record 7 of Set 9 | pedasi
# Processing Record 8 of Set 9 | kirkland lake
# Processing Record 9 of Set 9 | brawley
# Processing Record 10 of Set 9 | athens
# Processing Record 11 of Set 9 | yermekeyevo
# Processing Record 12 of Set 9 | trinidad
# Processing Record 13 of Set 9 | komsomolskiy
# Processing Record 14 of Set 9 | lasa
# Processing Record 15 of Set 9 | mouzakion
# City not found. Skipping...
# Processing Record 16 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 9 | kavieng
# Processing Record 18 of Set 9 | haines junction
# Processing Record 19 of Set 9 | soria
# Processing Record 20 of Set 9 | salo
# Processing Record 21 of Set 9 | kununurra
# Processing Record 22 of Set 9 | port blair
# Processing Record 23 of Set 9 | lervik
# Processing Record 24 of Set 9 | villazon
# Processing Record 25 of Set 9 | honningsvag
# Processing Record 26 of Set 9 | saint-georges
# Processing Record 27 of Set 9 | salgar
# Processing Record 28 of Set 9 | caluquembe
# Processing Record 29 of Set 9 | cap malheureux
# Processing Record 30 of Set 9 | rawson
# Processing Record 31 of Set 9 | wajima
# Processing Record 32 of Set 9 | missoula
# Processing Record 33 of Set 9 | akyab
# Processing Record 34 of Set 9 | ratnagiri
# Processing Record 35 of Set 9 | owando
# Processing Record 36 of Set 9 | zhizdra
# Processing Record 37 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 9 | nyurba
# Processing Record 39 of Set 9 | kushiro
# Processing Record 40 of Set 9 | binga
# Processing Record 41 of Set 9 | krasnoselkup
# Processing Record 42 of Set 9 | fez
# Processing Record 43 of Set 9 | les escoumins
# Processing Record 44 of Set 9 | namibe
# Processing Record 45 of Set 9 | nizhniy kuranakh
# Processing Record 46 of Set 9 | obluche
# City not found. Skipping...
# Processing Record 47 of Set 9 | hobyo
# Processing Record 48 of Set 9 | peyima
# Processing Record 49 of Set 9 | port macquarie
# Processing Record 50 of Set 9 | havre
# Processing Record 1 of Set 10 | ndele
# Processing Record 2 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 10 | guerrero negro
# Processing Record 4 of Set 10 | zaragoza
# Processing Record 5 of Set 10 | iskateley
# Processing Record 6 of Set 10 | maniitsoq
# Processing Record 7 of Set 10 | traverse city
# Processing Record 8 of Set 10 | bulgan
# Processing Record 9 of Set 10 | portland
# Processing Record 10 of Set 10 | sao jose da coroa grande
# Processing Record 11 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 12 of Set 10 | vyazma
# Processing Record 13 of Set 10 | dongfeng
# Processing Record 14 of Set 10 | hambantota
# Processing Record 15 of Set 10 | abu samrah
# Processing Record 16 of Set 10 | dauriya
# Processing Record 17 of Set 10 | bereda
# Processing Record 18 of Set 10 | vao
# Processing Record 19 of Set 10 | meulaboh
# Processing Record 20 of Set 10 | mazurivka
# Processing Record 21 of Set 10 | cabo san lucas
# Processing Record 22 of Set 10 | graham
# Processing Record 23 of Set 10 | simao
# Processing Record 24 of Set 10 | villaviciosa
# Processing Record 25 of Set 10 | tirumullaivasal
# Processing Record 26 of Set 10 | husavik
# Processing Record 27 of Set 10 | matamoros
# Processing Record 28 of Set 10 | imbituba
# Processing Record 29 of Set 10 | huarmey
# Processing Record 30 of Set 10 | leeton
# Processing Record 31 of Set 10 | prado
# Processing Record 32 of Set 10 | biskamzha
# Processing Record 33 of Set 10 | mount gambier
# Processing Record 34 of Set 10 | pisco
# Processing Record 35 of Set 10 | atasu
# Processing Record 36 of Set 10 | bara
# Processing Record 37 of Set 10 | hadimkoy
# City not found. Skipping...
# Processing Record 38 of Set 10 | marsh harbour
# Processing Record 39 of Set 10 | shihezi
# Processing Record 40 of Set 10 | erenhot
# Processing Record 41 of Set 10 | antalaha
# Processing Record 42 of Set 10 | shimanovsk
# Processing Record 43 of Set 10 | kosovska mitrovica
# Processing Record 44 of Set 10 | mopipi
# Processing Record 45 of Set 10 | shemonaikha
# Processing Record 46 of Set 10 | molo
# Processing Record 47 of Set 10 | asau
# Processing Record 48 of Set 10 | sao sebastiao
# Processing Record 49 of Set 10 | beisfjord
# Processing Record 50 of Set 10 | balatonfured
# Processing Record 1 of Set 11 | gamba
# Processing Record 2 of Set 11 | okato
# Processing Record 3 of Set 11 | dalbandin
# Processing Record 4 of Set 11 | kirakira
# Processing Record 5 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 6 of Set 11 | palmer
# Processing Record 7 of Set 11 | camacupa
# Processing Record 8 of Set 11 | legnica
# Processing Record 9 of Set 11 | vila velha
# Processing Record 10 of Set 11 | shenzhen
# Processing Record 11 of Set 11 | kaspiyskiy
# Processing Record 12 of Set 11 | casino
# Processing Record 13 of Set 11 | kholmogory
# Processing Record 14 of Set 11 | gorahun
# Processing Record 15 of Set 11 | upington
# Processing Record 16 of Set 11 | saint george
# Processing Record 17 of Set 11 | bull savanna
# Processing Record 18 of Set 11 | vanimo
# Processing Record 19 of Set 11 | chimoio
# Processing Record 20 of Set 11 | mayumba
# Processing Record 21 of Set 11 | manjacaze
# Processing Record 22 of Set 11 | meridian
# Processing Record 23 of Set 11 | leshukonskoye
# Processing Record 24 of Set 11 | coos bay
# Processing Record 25 of Set 11 | cockburn town
# Processing Record 26 of Set 11 | mana
# Processing Record 27 of Set 11 | seryshevo
# Processing Record 28 of Set 11 | qaqortoq
# Processing Record 29 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 30 of Set 11 | morehead
# Processing Record 31 of Set 11 | muros
# Processing Record 32 of Set 11 | san cristobal
# Processing Record 33 of Set 11 | provost
# Processing Record 34 of Set 11 | kiomboi
# Processing Record 35 of Set 11 | te horo
# Processing Record 36 of Set 11 | abha
# Processing Record 37 of Set 11 | baiyin
# Processing Record 38 of Set 11 | ust-nera
# Processing Record 39 of Set 11 | bairiki
# Processing Record 40 of Set 11 | aquiraz
# Processing Record 41 of Set 11 | cayenne
# Processing Record 42 of Set 11 | puqi
# Processing Record 43 of Set 11 | patiya
# Processing Record 44 of Set 11 | coahuayana
# Processing Record 45 of Set 11 | tiznit
# Processing Record 46 of Set 11 | xining
# Processing Record 47 of Set 11 | yar-sale
# Processing Record 48 of Set 11 | pokrovka
# Processing Record 49 of Set 11 | atakpame
# Processing Record 50 of Set 11 | tuni
# Processing Record 1 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 2 of Set 12 | jeremoabo
# Processing Record 3 of Set 12 | pauini
# Processing Record 4 of Set 12 | brae
# Processing Record 5 of Set 12 | college
# Processing Record 6 of Set 12 | auki
# Processing Record 7 of Set 12 | moron
# Processing Record 8 of Set 12 | onega
# Processing Record 9 of Set 12 | tahta
# Processing Record 10 of Set 12 | ubatuba
# Processing Record 11 of Set 12 | ca mau
# Processing Record 12 of Set 12 | waipawa
# Processing Record 13 of Set 12 | high level
# Processing Record 14 of Set 12 | bam
# Processing Record 15 of Set 12 | fortuna
# Processing Record 16 of Set 12 | cullman
# Processing Record 17 of Set 12 | santa rosa
# Processing Record 18 of Set 12 | chicama
# Processing Record 19 of Set 12 | manzhouli
# Processing Record 20 of Set 12 | dungarpur
# Processing Record 21 of Set 12 | yarmouth
# Processing Record 22 of Set 12 | yerofey pavlovich
# Processing Record 23 of Set 12 | vangaindrano
# Processing Record 24 of Set 12 | saint anthony
# Processing Record 25 of Set 12 | nyagan
# Processing Record 26 of Set 12 | ngunguru
# Processing Record 27 of Set 12 | orbetello
# Processing Record 28 of Set 12 | tahe
# Processing Record 29 of Set 12 | mount isa
# Processing Record 30 of Set 12 | saint-leu
# Processing Record 31 of Set 12 | itacare
# Processing Record 32 of Set 12 | marawi
# Processing Record 33 of Set 12 | bolshaya martynovka
# Processing Record 34 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 12 | murom
# Processing Record 36 of Set 12 | cikupa
# Processing Record 37 of Set 12 | luyang
# Processing Record 38 of Set 12 | tsiroanomandidy
# Processing Record 39 of Set 12 | cao bang
# Processing Record 40 of Set 12 | digby
# Processing Record 41 of Set 12 | eureka
# Processing Record 42 of Set 12 | lima
# Processing Record 43 of Set 12 | hounde
# Processing Record 44 of Set 12 | donaueschingen
# Processing Record 45 of Set 12 | yinchuan
# Processing Record 46 of Set 12 | nizwa
# Processing Record 47 of Set 12 | lahat
# Processing Record 48 of Set 12 | lavrentiya
# Processing Record 49 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 12 | parobe
# Processing Record 1 of Set 13 | waki
# Processing Record 2 of Set 13 | ngozi
# Processing Record 3 of Set 13 | bathsheba
# Processing Record 4 of Set 13 | rock sound
# Processing Record 5 of Set 13 | saint-pierre
# Processing Record 6 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 7 of Set 13 | szirmabesenyo
# Processing Record 8 of Set 13 | tiksi
# Processing Record 9 of Set 13 | villa altagracia
# Processing Record 10 of Set 13 | ushumun
# Processing Record 11 of Set 13 | margate
# Processing Record 12 of Set 13 | vardo
# Processing Record 13 of Set 13 | tetouan
# Processing Record 14 of Set 13 | muravlenko
# Processing Record 15 of Set 13 | gold coast
# Processing Record 16 of Set 13 | unity
# Processing Record 17 of Set 13 | yashkul
# Processing Record 18 of Set 13 | tonantins
# Processing Record 19 of Set 13 | ville-marie
# Processing Record 20 of Set 13 | omboue
# Processing Record 21 of Set 13 | sao joao da barra
# Processing Record 22 of Set 13 | tateyama
# Processing Record 23 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 24 of Set 13 | inongo
# Processing Record 25 of Set 13 | itaueira
# Processing Record 26 of Set 13 | nishihara
# Processing Record 27 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 28 of Set 13 | raudeberg
# Processing Record 29 of Set 13 | kieta
# Processing Record 30 of Set 13 | caravelas
# Processing Record 31 of Set 13 | totonicapan
# Processing Record 32 of Set 13 | mapiripan
# Processing Record 33 of Set 13 | ruteng
# Processing Record 34 of Set 13 | bikin
# Processing Record 35 of Set 13 | madaoua
# Processing Record 36 of Set 13 | manzanillo
# Processing Record 37 of Set 13 | xingyi
# Processing Record 38 of Set 13 | tabukiniberu
# City not found. Skipping...
# Processing Record 39 of Set 13 | baroy
# Processing Record 40 of Set 13 | pitimbu
# Processing Record 41 of Set 13 | riyadh
# Processing Record 42 of Set 13 | zhigansk
# Processing Record 43 of Set 13 | mariental
# Processing Record 44 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 46 of Set 13 | tran
# Processing Record 47 of Set 13 | harper
# Processing Record 48 of Set 13 | srandakan
# Processing Record 49 of Set 13 | mumford
# Processing Record 50 of Set 13 | kushima
# Processing Record 1 of Set 14 | aksu
# Processing Record 2 of Set 14 | ventspils
# Processing Record 3 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 14 | dhekiajuli
# Processing Record 5 of Set 14 | halifax
# Processing Record 6 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 7 of Set 14 | presidente epitacio
# Processing Record 8 of Set 14 | contamana
# Processing Record 9 of Set 14 | ucluelet
# Processing Record 10 of Set 14 | hodosa
# Processing Record 11 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 12 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 14 | semirom
# Processing Record 14 of Set 14 | vila
# Processing Record 15 of Set 14 | luba
# Processing Record 16 of Set 14 | ozernovskiy
# Processing Record 17 of Set 14 | maceio
# Processing Record 18 of Set 14 | helena
# Processing Record 19 of Set 14 | kloulklubed
# Processing Record 20 of Set 14 | matara
# Processing Record 21 of Set 14 | aswan
# Processing Record 22 of Set 14 | markova
# Processing Record 23 of Set 14 | gagino
# Processing Record 24 of Set 14 | waddan
# Processing Record 25 of Set 14 | besikduzu
# Processing Record 26 of Set 14 | christchurch
# Processing Record 27 of Set 14 | naifaru
# Processing Record 28 of Set 14 | ati
# Processing Record 29 of Set 14 | pietroasa
# Processing Record 30 of Set 14 | rivadavia
# Processing Record 31 of Set 14 | middelburg
# Processing Record 32 of Set 14 | bonoua
# Processing Record 33 of Set 14 | villahermosa
# Processing Record 34 of Set 14 | wanaka
# Processing Record 35 of Set 14 | entre rios
# Processing Record 36 of Set 14 | shelburne
# Processing Record 37 of Set 14 | hojai
# Processing Record 38 of Set 14 | jiangyou
# Processing Record 39 of Set 14 | najran
# Processing Record 40 of Set 14 | eldorado
# Processing Record 41 of Set 14 | honiara
# Processing Record 42 of Set 14 | havoysund
# Processing Record 43 of Set 14 | jacmel
# Processing Record 44 of Set 14 | cairns
# Processing Record 45 of Set 14 | launceston
# Processing Record 46 of Set 14 | boden
# Processing Record 47 of Set 14 | linares
# Processing Record 48 of Set 14 | zhezkazgan
# Processing Record 49 of Set 14 | mareeba
# Processing Record 50 of Set 14 | pozzallo
# Processing Record 1 of Set 15 | kajaani
# Processing Record 2 of Set 15 | souillac
# Processing Record 3 of Set 15 | codrington
# Processing Record 4 of Set 15 | gornopravdinsk
# Processing Record 5 of Set 15 | vila franca do campo
# Processing Record 6 of Set 15 | acapulco
# Processing Record 7 of Set 15 | atikokan
# Processing Record 8 of Set 15 | vieques
# Processing Record 9 of Set 15 | salinopolis
# Processing Record 10 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 15 | maragogi
# Processing Record 12 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 13 of Set 15 | nemuro
# Processing Record 14 of Set 15 | belyy yar
# Processing Record 15 of Set 15 | labuhan
# Processing Record 16 of Set 15 | lexington
# Processing Record 17 of Set 15 | panaba
# Processing Record 18 of Set 15 | anadyr
# Processing Record 19 of Set 15 | poim
# Processing Record 20 of Set 15 | moerai
# Processing Record 21 of Set 15 | kodinsk
# Processing Record 22 of Set 15 | kalach-na-donu
# Processing Record 23 of Set 15 | beringovskiy
# Processing Record 24 of Set 15 | tahoua
# Processing Record 25 of Set 15 | toora-khem
# Processing Record 26 of Set 15 | karachi
# Processing Record 27 of Set 15 | tazmalt
# Processing Record 28 of Set 15 | idritsa
# Processing Record 29 of Set 15 | preobrazheniye
# Processing Record 30 of Set 15 | henties bay
# Processing Record 31 of Set 15 | unye
# City not found. Skipping...
# Processing Record 32 of Set 15 | yulara
# Processing Record 33 of Set 15 | praya
# Processing Record 34 of Set 15 | loikaw
# Processing Record 35 of Set 15 | orange
# Processing Record 36 of Set 15 | mantua
# Processing Record 37 of Set 15 | puerto escondido
# Processing Record 38 of Set 15 | coxim
# Processing Record 39 of Set 15 | ardakan
# Processing Record 40 of Set 15 | bac lieu
# Processing Record 41 of Set 15 | iwaki
# Processing Record 42 of Set 15 | burlington
# Processing Record 43 of Set 15 | shubarkuduk
# Processing Record 44 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 15 | abengourou
# Processing Record 46 of Set 15 | bundaberg
# Processing Record 47 of Set 15 | austin
# Processing Record 48 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 49 of Set 15 | gorontalo
# Processing Record 50 of Set 15 | auka
# Processing Record 1 of Set 16 | phangnga
# Processing Record 2 of Set 16 | indiaroba
# Processing Record 3 of Set 16 | uarini
# Processing Record 4 of Set 16 | hervey bay
# Processing Record 5 of Set 16 | sampit
# Processing Record 6 of Set 16 | windhoek
# Processing Record 7 of Set 16 | tapaua
# City not found. Skipping...
# Processing Record 8 of Set 16 | maizuru
# Processing Record 9 of Set 16 | hihifo
# City not found. Skipping...
# Processing Record 10 of Set 16 | oriximina
# Processing Record 11 of Set 16 | alotau
# City not found. Skipping...
# Processing Record 12 of Set 16 | sakaiminato
# Processing Record 13 of Set 16 | liberal
# Processing Record 14 of Set 16 | nema
# Processing Record 15 of Set 16 | san antero
# Processing Record 16 of Set 16 | kangaatsiaq
# Processing Record 17 of Set 16 | emba
# Processing Record 18 of Set 16 | sindi
# Processing Record 19 of Set 16 | volchanets
# Processing Record 20 of Set 16 | pak phanang
# Processing Record 21 of Set 16 | kambove
# Processing Record 22 of Set 16 | dumka
# Processing Record 23 of Set 16 | lahad datu
# Processing Record 24 of Set 16 | egvekinot
# Processing Record 25 of Set 16 | izhma
# Processing Record 26 of Set 16 | paita
# Processing Record 27 of Set 16 | port lincoln
# Processing Record 28 of Set 16 | guaruja
# Processing Record 29 of Set 16 | paptalaya
# Processing Record 30 of Set 16 | barbar
# City not found. Skipping...
# Processing Record 31 of Set 16 | chagoda
# Processing Record 32 of Set 16 | murdochville
# Processing Record 33 of Set 16 | toftir
# City not found. Skipping...
# Processing Record 34 of Set 16 | kryve ozero
# Processing Record 35 of Set 16 | touros
# Processing Record 36 of Set 16 | ketchikan
# Processing Record 37 of Set 16 | riachao das neves
# Processing Record 38 of Set 16 | morros
# Processing Record 39 of Set 16 | basco
# Processing Record 40 of Set 16 | pacific grove
# Processing Record 41 of Set 16 | manggar
# Processing Record 42 of Set 16 | lashio
# Processing Record 43 of Set 16 | mata
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
# Re-order columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Castro      BR -24.7911  -50.0119     64.60        98         100
# 1      Sao Filipe      CV  14.8961  -24.4956     72.09        70          99
# 2         Mataura      NZ -46.1927  168.8643     48.47        89          80
# 3         Kahului      US  20.8947 -156.4700     69.06        82           0
# 4         Aksarka      RU  66.5606   67.7975    -14.89        99          64
# 5     Nikitinskiy      RU  54.5845   86.0115     -5.64       100          97
# 6          Dikson      RU  73.5069   80.5464      6.53        93         100
# 7           Vaini      TO -21.2000 -175.2000     82.24        79          94
# 8  Port Elizabeth      ZA -33.9180   25.5701     74.10        68          75
# 9    Longyearbyen      SJ  78.2186   15.6401     12.04        62           0
#
#    Wind Speed Current Description
# 0        6.42     overcast clouds
# 1       12.08     overcast clouds
# 2        2.42       broken clouds
# 3        4.61           clear sky
# 4        6.78       broken clouds
# 5        3.74     overcast clouds
# 6       19.19     overcast clouds
# 7       18.99     overcast clouds
# 8       19.57       broken clouds
# 9       13.80           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
